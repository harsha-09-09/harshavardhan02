# %%
print("this cell is used for github sessions")
# Out:
# this cell is used for github sessions

# %%
import numpy as np

# %%
arr1 = np.array([1,2,3,4])
arr1
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# **OR**

# %%
l1 = [1,2,3,4]
arr1 = np.array(l1)
arr1
# Out:
# array([1, 2, 3, 4])

# %%
arr1.ndim
# Out:
# 1

# %%
arr1.dtype
# Out:
# dtype('int64')

# %%
type(arr1)
# Out:
# numpy.ndarray

# %%
arr1.shape   # how many elements are available
# only 4 values
# Out:
# (4,)

# %%
arr1.ndim
arr1.shape
arr1.size
type(arr1)
# Out:
# numpy.ndarray

# %%
# np.array(object, dtype = None)
# np.array(l1)
# np.array(l1,l2)    # wrong
l1 = [1,2,3,4]
l2 = [10,20,30,40]
l = [l1,l2]
arr2 = np.array(l)    # correct
arr2
# Out:
# array([[ 1,  2,  3,  4],
#        [10, 20, 30, 40]])

# %%
arr2.ndim  # 2
# Out:
# 2

# %%
arr2.dtype
# Out:
# dtype('int64')

# %%
arr2.size
# Out:
# 8

# %%
arr2.shape    # 2 rows and 4 columns
# Out:
# (2, 4)

# %%
type(arr2)
# Out:
# numpy.ndarray

# %%
l1 = [1,2,3,4]
l2 = [10,20,30,40]
l3 = ['a','b','c','d']
l = [l1,l2,l3]
arr2 = np.array(l)

# %%
print(arr2)
print(arr2.ndim)
print(arr2.shape)
print(arr2.size)
print(type(arr2))
print(type(l1))
# Out:
# [['1' '2' '3' '4']
#  ['10' '20' '30' '40']
#  ['a' 'b' 'c' 'd']]
# 2
# (3, 4)
# 12
# <class 'numpy.ndarray'>
# <class 'list'>

# %%
l1 = [1,2,3,4]
arr1 = np.array(l1)
arr1
# Out:
# array([1, 2, 3, 4])

# %%
arr1 = np.array([l1])
arr1
# Out:
# array([[1, 2, 3, 4]])

# %%
arr1 = np.array([[l1]])
print(arr1)
print(arr1.ndim)
# Out:
# [[[1 2 3 4]]]
# 3

# %%
arr1 = np.array([[[l1]]]).ndim
arr1
# Out:
# 4

# %%
l1 = [1,2,3,4]
l2 = [10,20,30,40]
l3 = ['a','b','c','d']
np.array([[l1,l2,l3]])
# Out:
# array([[['1', '2', '3', '4'],
#         ['10', '20', '30', '40'],
#         ['a', 'b', 'c', 'd']]], dtype='<U21')

# %%
# m,n,k
# im taking a list l having k values

# %%
# m,n,2
# im taking a list l = [10,20]

# %%
# n : im taking number of 'l'
# m,3,2
# 2 ===>

# %%
# n4,m3,k2
# k = [10,20]
